# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color = 'red', marker = '+')
plt.plot(df.area,reg.predict(df[['area']]))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[11], line 5
#       3 plt.ylabel('price')
#       4 plt.scatter(df.area,df.price,color = 'red', marker = '+')
# ----> 5 plt.plot(df.area,reg.predict(df[['area']]))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:275, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# --> 275     check_is_fitted(self)
# ...

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(pd.DataFrame([[3300]], columns = ['area']))
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict(pd.DataFrame([[5000]], columns = ['area']))
# Out:
# array([859554.79452055])

# %%
reg.predict([[5000]])
# Out:
# C:\Users\gurua\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
df2 = pd.read_csv('areas.csv')

# %%
df2
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
predicted_price = reg.predict(df2)
predicted_price
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df2['prices'] = predicted_price

# %%
df2
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df2.to_csv('predicted_prices.csv',index = False)

# %%
d = pd.read_csv('canada_per_capita_income.csv')

# %%
d
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
reg2 = linear_model.LinearRegression()

# %%
reg2.fit(d[['year']], d['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg2.predict(pd.DataFrame([[2020]],columns =['year']))
# Out:
# array([41288.69409442])

# %%
# %matplotlib inline
plt.scatter(d.year, d['per capita income (US$)'])
plt.plot(d.year, reg2.predict(d[['year']]))

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(reg2,f)
